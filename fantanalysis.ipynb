# %%
import pandas as pd

# Display options
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

# %%
# Load Data
def loadData(name):
    return pd.read_excel(name, header=1)

# %%
df21 = loadData("Statistiche_Fantacalcio_2021-22.xlsx")
df20 = loadData("Statistiche_Fantacalcio_2020-21.xlsx")
df19 = loadData("Statistiche_Fantacalcio_2019-20.xlsx")
df18 = loadData("Statistiche_Fantacalcio_2018-19.xlsx")
df17 = loadData("Statistiche_Fantacalcio_2017-18.xlsx")

# %%
# separate ruoli
def sepRuoli(df, ruolo):
    return df.loc[df['R'] == ruolo]

# %%
df21p = sepRuoli(df21, "P")
df20p = sepRuoli(df20, "P")
df19p = sepRuoli(df19, "P")
df18p = sepRuoli(df18, "P")
df17p = sepRuoli(df17, "P")
dfsp = [df21p, df20p, df19p, df18p, df17p]

df21d = sepRuoli(df21, "D")
df20d = sepRuoli(df20, "D")
df19d = sepRuoli(df19, "D")
df18d = sepRuoli(df18, "D")
df17d = sepRuoli(df17, "D")
dfsd = [df21d, df20d, df19d, df18d, df17d]

df21c = sepRuoli(df21, "C")
df20c = sepRuoli(df20, "C")
df19c = sepRuoli(df19, "C")
df18c = sepRuoli(df18, "C")
df17c = sepRuoli(df17, "C")
dfsc = [df21c, df20c, df19c, df18c, df17c]

df21a = sepRuoli(df21, "A")
df20a = sepRuoli(df20, "A")
df19a = sepRuoli(df19, "A")
df18a = sepRuoli(df18, "A")
df17a = sepRuoli(df17, "A")
dfsa = [df21a, df20a, df19a, df18a, df17a]

# %% [markdown]
# #### Portieri

# %%
d
# Out:
#            Id        Pg        Mv        Mf        Gf  Gs  Rp        Rc  \
# Id   1.000000 -0.434804 -0.152659 -0.196299 -0.341545 NaN NaN -0.309317
# Pg  -0.434804  1.000000  0.532010  0.603416  0.794369 NaN NaN  0.453310
# Mv  -0.152659  0.532010  1.000000  0.980375  0.377492 NaN NaN  0.202091
# Mf  -0.196299  0.603416  0.980375  1.000000  0.505601 NaN NaN  0.288908
# Gf  -0.341545  0.794369  0.377492  0.505601  1.000000 NaN NaN  0.518168
# Gs        NaN       NaN       NaN       NaN       NaN NaN NaN       NaN
# Rp        NaN       NaN       NaN       NaN       NaN NaN NaN       NaN
# Rc  -0.309317  0.453310  0.202091  0.288908  0.518168 NaN NaN  1.000000
# R+  -0.307963  0.458907  0.202431  0.291342  0.507797 NaN NaN  0.974214
# R-  -0.230429  0.317612  0.147306  0.205425  0.407482 NaN NaN  0.801678
# Ass -0.323367  0.671081  0.338333  0.411679  0.533806 NaN NaN  0.483478
# Amm -0.313555  0.743132  0.371972  0.435161  0.693629 NaN NaN  0.392301
# ...
